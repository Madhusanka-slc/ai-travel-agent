# %%
import requests

# %%
url = "http://127.0.0.1:8080/hello-world"
r=requests.get(url)

# %%
r.json()
# Out:
# {'hello': 'read-world', 'Debug': True}

# %%
print(r.json())
# Out:
# {'hello': 'read-world', 'Debug': True}

# %%
w=requests.post(url)

# %%
w.json()
# Out:
# {'hello': 'write-world', 'Debug': True}
