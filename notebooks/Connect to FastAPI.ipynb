# %%
import requests

# %%
url = "http://127.0.0.1:8080/hello-world"
r=requests.get(url)

# %%
r.json()
# Out:
# {'hello': 'read-world', 'Debug': True}

# %%
print(r.json())
# Out:
# {'hello': 'read-world', 'Debug': True}

# %%
w=requests.post(url)

# %%
w.json()
# Out:
# {'hello': 'write-world', 'Debug': True}

# %%
url2 = "http://127.0.0.1:8080/flights"
r2=requests.get(url2)
r2.json()
# Out:
# [{'id': 0,
#   'flightDate': '2022-04-17',
#   'startingAirport': 'ATL',
#   'destinationAirport': 'BOS',
#   'isBasicEconomy': False,
#   'isRefundable': False,
#   'isNonStop': False,
#   'segmentsAirlineName': 'American Airlines||American Airlines',
#   'totalFare': 273},
#  {'id': 1,
#   'flightDate': '2022-04-17',
#   'startingAirport': 'ATL',
#   'destinationAirport': 'BOS',
#   'isBasicEconomy': False,
#   'isRefundable': False,
#   'isNonStop': False,
#   'segmentsAirlineName': 'Spirit Airlines||Spirit Airlines',
#   'totalFare': 301},
#  {'id': 2,
#   'flightDate': '2022-04-17',
#   'startingAirport': 'ATL',
#   'destinationAirport': 'BOS',
#   'isBasicEconomy': False,
#   'isRefundable': False,
#   'isNonStop': False,
#   'segmentsAirlineName': 'United||United',
#   'totalFare': 352},
#  {'id': 3,
#   'flightDate': '2022-04-17',
#   'startingAirport': 'ATL',
#   'destinationAirport': 'BOS',
#   'isBasicEconomy': False,
#   'isRefundable': False,
#   'isNonStop': True,
# ...

# %%
url3 = "http://127.0.0.1:8080/flights/2"
r3=requests.get(url3)
r3.json()
# Out:
# {'id': 2,
#  'flightDate': '2022-04-17',
#  'startingAirport': 'ATL',
#  'destinationAirport': 'BOS',
#  'isBasicEconomy': False,
#  'isRefundable': False,
#  'isNonStop': False,
#  'segmentsAirlineName': 'United||United',
#  'totalFare': 352}
